# %% [markdown]
# <a href="https://colab.research.google.com/github/razomadeleine3-maker/LYRIC.M/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# Colores ANSI
BLANCO = "\033[37m"
ROJO = "\033[91m"
VERDE = "\033[32m"
AMARILLO = "\033[93m"
AZUL = "\033[34m"
MAGENTA = "\033[95m"
CYAN = "\033[36m"

def escribir_texto(texto, tiempo_total_por_texto, color, salto_de_linea, tiempo_de_espera_final):
    tiempo_de_espera_por_letra = tiempo_total_por_texto / len(texto)

    print(color, end = "")

    for letra in texto:
        time.sleep(tiempo_de_espera_por_letra)
        print(letra, end = "", flush = True)

    if salto_de_linea:
        print()

    if tiempo_de_espera_final:
        time.sleep(tiempo_de_espera_final)

# (texto, tiempo_total_por_texto, color, salto_de_linea, tiempo_de_espera_final)
# el tiempo es en segundos
letra_rock_that_body = [
    ("I WANT YOU TO", 0.9, BLANCO, True, None),
    ("LOVE MEEEEE", 2.3, BLANCO, True, 0.15),
    ("love meeeee", 2.3, ROJO, True, 0.25),
    ("LOVE MEEEEE", 2.8, BLANCO, True, 0.3),
    ("love meeeee (oh baby)", 3.30, ROJO, True, None),
    ("LOVE MEEEEE", 2.25, BLANCO, True, 0.28),
    ("love meeeee", 1.30, ROJO, True, 0.15),
    ("LOVE MEEEEE", 1.25, BLANCO, True, 0.30),
    ("love meeeee", 1, ROJO, True, None),
    ("LOVE MEEEEE", 1, BLANCO, True, None),
    ("(YEAH,yeah,yeah,yeah,yeah,yeah)", 3.30, ROJO, True, None),
    ("(OH BABY)", 1, CYAN, True, None),
    ("LOVE MEEEEE", 1, BLANCO, True, None),
    ("(OH LOVE ME)", 2, ROJO, True, None),
    ("LOVE MEEEEE", 1, CYAN, False, None),

]

letra_perlas_negras = [
    ("Perlas negras con ", 1, AMARILLO, False, None),
    ("Red", 0.5, ROJO, False, None),
    ("Bull", 0.5, BLANCO, True, 0.3),
    ("Que no falte la actitud", 2.2, AMARILLO, True, 0.3),
    ("El amorrr pal ataurrr", 2.25, AMARILLO, True, None),
    ("Sepsi dance", 1, CYAN, True, None),
    ("Se pega un touuuur", 1.77, AMARILLO, True, 0.15),
]

for texto, tiempo_total_por_texto, color, salto_de_linea, tiempo_de_espera_final in letra_rock_that_body:
    escribir_texto(texto, tiempo_total_por_texto, color, salto_de_linea, tiempo_de_espera_final)
# Out:
# I WANT YOU TO
# LOVE MEEEEE
# love meeeee
# LOVE MEEEEE
# love meeeee (oh baby)
# LOVE MEEEEE
# love meeeee
# LOVE MEEEEE
# love meeeee
# LOVE MEEEEE
# (YEAH,yeah,yeah,yeah,yeah,yeah)
# (OH BABY)
# LOVE MEEEEE
# (OH LOVE ME)
# LOVE MEEEEE
